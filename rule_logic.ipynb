# %%
import pandas as pd
import re
from collections import defaultdict
import textwrap

# %%
INPUT_FILE = "../analysis-tja/plots_html/UNIT1/formulas_multivariate.csv"
WRAP_WIDTH = 150

# %%
df = pd.read_csv(INPUT_FILE)
df = df.loc[:, ~df.columns.str.contains("^Unnamed")]
df.reset_index(drop=True, inplace=True)
df = df.drop_duplicates(subset=["area_name", "tag_name"], keep="first").reset_index(drop=True)

# %%
# Parse formula linear
def parse_linear_formula(formula: str):
    lhs, rhs = formula.split("=", 1)
    target = lhs.strip()
    rhs = rhs.replace("-", "+ -")
    parts = [p.strip() for p in rhs.split("+") if p.strip()]

    intercept = 0.0
    terms = []

    for p in parts:
        if re.fullmatch(r"-?\d+(\.\d+)?", p):
            intercept = float(p)
            continue
        if "*" in p:
            coef, tag = p.split("*", 1)
            try:
                float(coef.strip())
                terms.append(f"{coef.strip()}*({tag.strip()})")
            except ValueError:
                pass

    model_eq = str(intercept)
    if terms:
        model_eq += " + " + " + ".join(terms)

    model_eq = model_eq.replace("+ -", "- ")
    return target, model_eq

# %%
# dictionary RULES per area dan tag
RULES = defaultdict(lambda: defaultdict(list))
for _, r in df.iterrows():
    target, model_eq = parse_linear_formula(r["formula"])
    logic_expr = f"( {target} {r['simbol']} {model_eq} )"
    RULES[r["area_name"]][r["tag_name"]].append(logic_expr)

# %%
# Fungsi tag/block
def wrap_tag(expr):
    return f"({expr})" if not expr.startswith("(") else expr

def build_block(expr_list, op="AND"):
    if len(expr_list) == 1:
        return wrap_tag(expr_list[0])
    return f"({f' {op} '.join(expr_list)})"

def build_engineer_logic(rules_by_area, area, block_definitions, outer_op="OR"):
    blocks_expr = []
    for block in block_definitions:
        tags = block["group"]
        op = block.get("op", "AND")
        tag_exprs = []
        for tag in tags:
            if tag not in rules_by_area[area]:
                raise ValueError(f"Tag '{tag}' tidak ada di area '{area}'")
            tag_exprs.append(wrap_tag(rules_by_area[area][tag][0]))
        blocks_expr.append(build_block(tag_exprs, op))
    return build_block(blocks_expr, outer_op)

# %%
# ENGINEER_LOGIC_BY_AREA
ENGINEER_LOGIC_BY_AREA = [
    # ---------------- FURNACE BACK AND RIGHT ----------------
    {
        "area": "FURNACE BACK AND RIGHT",
        "expression": [
            {"group": ["SH.FIN.OUT HEADER R OUT GAS TEMP", "STEAM FLOW"], "op": "AND"},
            {"group": ["STEAM TEMP OUT PLATEN SH"]},
            {"group": ["SH 1ST SPRAY WATER FLOW"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- FURNACE BACK AND LEFT ----------------
    {
        "area": "FURNACE FRONT AND LEFT",
        "expression": [
            {"group": ["SH.FIN.OUT HEADER L OUT GAS TEMP", "STEAM FLOW"], "op": "AND"},
            {"group": ["STEAM TEMP OUT PLATEN SH"]},
            {"group": ["SH 1ST SPRAY WATER FLOW"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- PANEL SH L ----------------
    {
        "area": "PANEL SH L",
        "expression": [
            {"group": ["SH.FIN.OUT HEADER L OUT GAS TEMP", "SH 1ST SPRAY WATER FLOW"], "op": "AND"},
            {"group": ["SH.FIN.OUT HEADER L OUT GAS TEMP", "SH 2ND SPRAY IN STM TEMP(L)"], "op": "AND"},
            {"group": ["DELTA STEAM TEMP AT PANEL-PLATEN SH"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- PANEL SH R ----------------
    {
        "area": "PANEL SH R",
        "expression": [
            {"group": ["SH.FIN.OUT HEADER R OUT GAS TEMP", "SH 1ST SPRAY WATER FLOW"], "op": "AND"},
            {"group": ["SH.FIN.OUT HEADER R OUT GAS TEMP", "SH 2ND SPRAY IN STM TEMP(R)"], "op": "AND"},
            {"group": ["DELTA STEAM TEMP AT PANEL-PLATEN SH"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- REHEAT L ----------------
    {
        "area": "REHEAT L",
        "expression": [
            {"group": ["L RH OUT STM TEMP", "SH.FIN.OUT HEADER L OUT GAS TEMP"], "op": "AND"},
            {"group": ["MAIN STM TEMP", "SH.FIN.OUT HEADER L OUT GAS TEMP"], "op": "AND"},
            {"group": ["Delta Steam Temp Platen RH - Final RH"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- REHEAT R ----------------
    {
        "area": "REHEAT R",
        "expression": [
            {"group": ["R RH OUT STM TEMP", "SH.FIN.OUT HEADER R OUT GAS TEMP"], "op": "AND"},
            {"group": ["MAIN STM TEMP", "SH.FIN.OUT HEADER R OUT GAS TEMP"], "op": "AND"},
            {"group": ["Delta Steam Temp Platen RH - Final RH"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- LTSH L ----------------
    {
        "area": "LTSH L",
        "expression": [
            {"group": ["SH 1ST SPRAY IN STM TEMP(L)", "SH.FIN.OUT HEADER L OUT GAS TEMP"], "op": "AND"},
            {"group": ["Delta Pressure"]},
            {"group": ["Delta Temperatur"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- LTSH R ----------------
    {
        "area": "LTSH R",
        "expression": [
            {"group": ["SH 1ST SPRAY IN STM TEMP(R)", "SH.FIN.OUT HEADER R OUT GAS TEMP"], "op": "AND"},
            {"group": ["Delta Pressure"]},
            {"group": ["Delta Temperatur"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- ECONOMIZER L ----------------
    {
        "area": "ECONOMIZER L",
        "expression": [
            {"group": ["Delta Pressure"]},
            {"group": ["Delta Temperatur"]},
            {"group": ["LMTD"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- ECONOMIZER R ----------------
    {
        "area": "ECONOMIZER R",
        "expression": [
            {"group": ["Delta Pressure"]},
            {"group": ["Delta Temperatur"]},
            {"group": ["LMTD"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- APH L ----------------
    {
        "area": "APH L",
        "expression": [
            {"group": ["Delta Pressure"]},
            {"group": ["Delta Temperatur"]},
            {"group": ["LMTD"]}
        ],
        "outer_op": "OR"
    },
    # ---------------- APH R ----------------
    {
        "area": "APH R",
        "expression": [
            {"group": ["Delta Pressure"]},
            {"group": ["Delta Temperatur"]},
            {"group": ["LMTD"]}
        ],
        "outer_op": "OR"
    }
]

# %%
# Build semua area otomatis
FINAL_RULES = {}
for area_def in ENGINEER_LOGIC_BY_AREA:
    area = area_def["area"]
    final_expr = build_engineer_logic(RULES, area, area_def["expression"], outer_op=area_def.get("outer_op", "OR"))
    FINAL_RULES[area] = final_expr

    print("="*100)
    print(area, ":\n")
    print(textwrap.fill(final_expr, WRAP_WIDTH))
    print()
# Out:
# ====================================================================================================
# FURNACE BACK AND RIGHT :
#
# ((( EWS102/10DAS0E:TC1E047203.PNT > 34.706 + 0.096*(EWS102/10DAS0O:AI1O013305.PNT) + 1.018*(EWS102/10DAS0D:TC1D027203.PNT) ) AND (
# EWS102/10DISP:STEAMFLOWB.PNT < -69.301 + 1.084*(EWS102/10DAS0O:AI1O013305.PNT) + 254.241*(EWS102/10DAS0J:PT1J010805.PNT) )) OR (
# EWS102/10DAS0A:TC1A012101.PNT > -86.282 - 0.055*(EWS102/10DAS0O:AI1O013305.PNT) + 1.128*(EWS102/10DAS0A:TC1A012105.PNT) ) OR (
# EWS102/10DAS0A:FT1A010401.PNT > -0.677 + 0.028*(EWS102/10DAS0O:AI1O013305.PNT) + 0.923*(EWS102/10DAS0A:FT1A010503.PNT) ))
#
# ====================================================================================================
# FURNACE FRONT AND LEFT :
#
# ((( EWS102/10DAS0E:TC1E047103.PNT > 88.53 + 0.094*(EWS102/10DAS0O:AI1O013305.PNT) + 0.909*(EWS102/10DAS0D:TC1D027101.PNT) ) AND (
# EWS102/10DISP:STEAMFLOWB.PNT < -69.301 + 1.084*(EWS102/10DAS0O:AI1O013305.PNT) + 254.241*(EWS102/10DAS0J:PT1J010805.PNT) )) OR (
# EWS102/10DAS0A:TC1A012101.PNT > -86.282 - 0.055*(EWS102/10DAS0O:AI1O013305.PNT) + 1.128*(EWS102/10DAS0A:TC1A012105.PNT) ) OR (
# EWS102/10DAS0A:FT1A010503.PNT > 8.682 - 0.019*(EWS102/10DAS0O:AI1O013305.PNT) + 0.800*(EWS102/10DAS0A:FT1A010401.PNT) ))
#
# ====================================================================================================
# PANEL SH L :
#
# ((( EWS102/10DAS0E:TC1E047103.PNT > 88.53 + 0.094*(EWS102/10DAS0O:AI1O013305.PNT) + 0.909*(EWS102/10DAS0D:TC1D027101.PNT) ) AND (
# EWS102/10DAS0A:FT1A010503.PNT < 7.357 - 0.040*(EWS102/10DAS0O:AI1O013305.PNT) + 0.847*(EWS102/10DAS0A:FT1A010401.PNT) )) OR ((
# EWS102/10DAS0E:TC1E047103.PNT > 88.53 + 0.094*(EWS102/10DAS0O:AI1O013305.PNT) + 0.909*(EWS102/10DAS0D:TC1D027101.PNT) ) AND (
# EWS102/10DAS0A:TC1A012101.PNT < -62.67 + 0.000*(EWS102/10DAS0O:AI1O013305.PNT) + 1.040*(EWS102/10DAS0A:TC1A012105.PNT) )) OR (
# (EWS102/10DAS0A:TC1A012101.PNT - (EWS102/10DAS0A:TC1A011406.PNT + EWS102/10DAS0A:TC1A011504.PNT)/2) < -572.471 - 0.016*(EWS102/10DAS0O:AI1O013305.PNT)
# + 1.253*(EWS102/10DAS0A:TC1A012105.PNT) ))
#
# ====================================================================================================
# PANEL SH R :
#
# ((( EWS102/10DAS0E:TC1E047203.PNT > 34.706 + 0.096*(EWS102/10DAS0O:AI1O013305.PNT) + 1.018*(EWS102/10DAS0D:TC1D027203.PNT) ) AND (
# EWS102/10DAS0A:FT1A010401.PNT < 0.971 - 0.008*(EWS102/10DAS0O:AI1O013305.PNT) + 0.991*(EWS102/10DAS0A:FT1A010503.PNT) )) OR ((
# EWS102/10DAS0E:TC1E047203.PNT > 34.706 + 0.096*(EWS102/10DAS0O:AI1O013305.PNT) + 1.018*(EWS102/10DAS0D:TC1D027203.PNT) ) AND (
# EWS102/10DAS0A:TC1A011601.PNT < 178.615 - 0.032*(EWS102/10DAS0O:AI1O013305.PNT) + 0.636*(EWS102/10DAS0A:TC1A012101.PNT) )) OR (
# (EWS102/10DAS0A:TC1A011601.PNT - (EWS102/10DAS0A:TC1A011405.PNT + EWS102/10DAS0A:TC1A011505.PNT)/2) < 83.041 - 0.044*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.886*(EWS102/10DAS0A:FT1A010503.PNT) ))
#
# ====================================================================================================
# REHEAT L :
#
# ((( (EWS102/10DAS0A:TC1A012203.PNT + EWS102/10DAS0A:TC1A012305.PNT)/2 < 17.454 + 0.015*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.961*(EWS102/10DAS0A:TC1A012305.PNT) ) AND ( EWS102/10DAS0E:TC1E047103.PNT > 88.53 + 0.094*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.909*(EWS102/10DAS0D:TC1D027101.PNT) )) OR (( EWS102/10DAS0M:TC1M053102.PNT < 2.29 - 0.014*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.998*(EWS102/10DISP:MSTT.PNT) ) AND ( EWS102/10DAS0E:TC1E047103.PNT > 88.53 + 0.094*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.909*(EWS102/10DAS0D:TC1D027101.PNT) )) OR ( ((EWS102/10DAS0A:TC1A012203.PNT + EWS102/10DAS0A:TC1A012305.PNT)/2 - EWS102/10DAS0A:TC1A011507.PNT) <
# 213.521 - 0.040*(EWS102/10DAS0O:AI1O013305.PNT) + 0.775*(EWS102/10DAS0A:FT1A010401.PNT) ))
#
# ====================================================================================================
# REHEAT R :
#
# ((( (EWS102/10DAS0A:TC1A012204.PNT + EWS102/10DAS0A:TC1A012306.PNT)/2 < 14.979 - 0.008*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.967*(EWS102/10DAS0A:TC1A012306.PNT) ) AND ( EWS102/10DAS0E:TC1E047203.PNT > 34.706 + 0.096*(EWS102/10DAS0O:AI1O013305.PNT) +
# 1.018*(EWS102/10DAS0D:TC1D027203.PNT) )) OR (( EWS102/10DAS0M:TC1M053102.PNT < 2.29 - 0.014*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.998*(EWS102/10DISP:MSTT.PNT) ) AND ( EWS102/10DAS0E:TC1E047203.PNT > 34.706 + 0.096*(EWS102/10DAS0O:AI1O013305.PNT) +
# 1.018*(EWS102/10DAS0D:TC1D027203.PNT) )) OR ( ((EWS102/10DAS0A:TC1A012204.PNT + EWS102/10DAS0A:TC1A012306.PNT)/2 - EWS102/10DAS0A:TC1A011506.PNT) <
# -634.222 - 0.059*(EWS102/10DAS0O:AI1O013305.PNT) + 2.777*(EWS102/10DAS0A:TC1A012205.PNT) ))
#
# ====================================================================================================
# LTSH L :
#
# ((( EWS102/10DAS0A:TC1A011503.PNT < 4.696 + 0.008*(EWS102/10DAS0O:AI1O013305.PNT) + 0.974*(EWS102/10DAS0A:TC1A011404.PNT) ) AND (
# EWS102/10DAS0E:TC1E047103.PNT > 88.53 + 0.094*(EWS102/10DAS0O:AI1O013305.PNT) + 0.909*(EWS102/10DAS0D:TC1D027101.PNT) )) OR (
# ((EWS102/10DAS0E:PT1E032601.PNT + EWS102/10DAS0D:PT1D012602.PNT)/2 - EWS102/10DAS0E:PT1E032602.PNT) > 145.475 - 0.016*(EWS102/10DAS0O:AI1O013305.PNT)
# + 0.936*(EWS102/10DAS0E:CT1E046304.PNT) ) OR ( (EWS102/10DAS0D:TC1D027101.PNT - EWS102/10DAS0E:TC1E047101.PNT) < -165.94 +
# 0.030*(EWS102/10DAS0O:AI1O013305.PNT) + 0.477*(EWS102/10DAS0E:TC1E047103.PNT) ))
#
# ====================================================================================================
# LTSH R :
#
# ((( EWS102/10DAS0A:TC1A011404.PNT < -12.367 + 0.003*(EWS102/10DAS0O:AI1O013305.PNT) + 1.031*(EWS102/10DAS0A:TC1A011503.PNT) ) AND (
# EWS102/10DAS0E:TC1E047203.PNT > 34.706 + 0.096*(EWS102/10DAS0O:AI1O013305.PNT) + 1.018*(EWS102/10DAS0D:TC1D027203.PNT) )) OR (
# ((EWS102/10DAS0E:PT1E033601.PNT + EWS102/10DAS0D:PT1D013602.PNT)/2 - EWS102/10DAS0E:PT1E033602.PNT) > 72.328 - 0.004*(EWS102/10DAS0O:AI1O013305.PNT) +
# 1.062*(EWS102/10DAS0E:CT1E046304.PNT) ) OR ( (EWS102/10DAS0D:TC1D027203.PNT - EWS102/10DAS0E:TC1E047102.PNT) < -125.07 +
# 0.044*(EWS102/10DAS0O:AI1O013305.PNT) + 0.403*(EWS102/10DAS0E:TC1E047203.PNT) ))
#
# ====================================================================================================
# ECONOMIZER L :
#
# (( (EWS102/10DAS0E:PT1E032602.PNT - (EWS102/10DAS0E:PT1E032603.PNT + EWS102/10DAS0D:PT1D012603.PNT)/2) > 33.91 - 0.000*(EWS102/10DAS0O:AI1O013305.PNT)
# + 1.919*(EWS102/10DAS0D:CT1D013307.PNT) ) OR ( (EWS102/10DAS0E:TC1E047101.PNT - EWS102/10DAS0E:TC1E047201.PNT) < -88.9 -
# 0.013*(EWS102/10DAS0O:AI1O013305.PNT) + 0.561*(EWS102/10DAS0A:TC1A012205.PNT) ) OR ( ((EWS102/10DAS0E:TC1E047101.PNT - EWS102/10DAS0A:TC1A012205.PNT)
# - (EWS102/10DAS0E:TC1E047201.PNT - EWS102/10DAS0A:TC1A011401.PNT)) / ln((EWS102/10DAS0E:TC1E047101.PNT - EWS102/10DAS0A:TC1A012205.PNT) /
# (EWS102/10DAS0E:TC1E047201.PNT - EWS102/10DAS0A:TC1A011401.PNT)) > -122.637 - 0.050*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.571*(EWS102/10DAS0E:TC1E047102.PNT) ))
#
# ====================================================================================================
# ECONOMIZER R :
#
# (( (EWS102/10DAS0E:PT1E033602.PNT - (EWS102/10DAS0E:PT1E033603.PNT + EWS102/10DAS0E:PT1E032604.PNT)/2) > 205.295 +
# 0.097*(EWS102/10DAS0O:AI1O013305.PNT) + 1.697*(EWS102/10DAS0D:CT1D013307.PNT) ) OR ( (EWS102/10DAS0E:TC1E047102.PNT - EWS102/10DAS0E:TC1E047202.PNT) <
# 2.241 - 0.014*(EWS102/10DAS0O:AI1O013305.PNT) + 0.147*(EWS102/10DAS0A:TC1A011503.PNT) ) OR ( ((EWS102/10DAS0E:TC1E047102.PNT -
# EWS102/10DAS0A:TC1A012303.PNT) - (EWS102/10DAS0E:TC1E047202.PNT - EWS102/10DAS0A:TC1A011401.PNT)) / ln((EWS102/10DAS0E:TC1E047102.PNT -
# EWS102/10DAS0A:TC1A012303.PNT) / (EWS102/10DAS0E:TC1E047202.PNT - EWS102/10DAS0A:TC1A011401.PNT)) > -79.069 - 0.037*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.567*(EWS102/10DAS0B:TC1B023202.PNT) ))
#
# ====================================================================================================
# APH L :
#
# (( ((EWS102/10DAS0E:PT1E032603.PNT + EWS102/10DAS0D:PT1D012603.PNT)/2 - EWS102/10DAS0D:PT1D013603.PNT) > 233.559 +
# 0.280*(EWS102/10DAS0O:AI1O013305.PNT) + 8.491*(EWS102/10DAS0D:CT1D013307.PNT) ) OR ( (EWS102/10DAS0E:TC1E047201.PNT - (EWS102/10DAS0D:RT1D012706.PNT +
# EWS102/10DAS0D:RT1D026402.PNT + EWS102/10DAS0D:RT1D012307.PNT)/3) < 116.901 + 0.091*(EWS102/10DAS0O:AI1O013305.PNT) + 0.145*(EWS102/10FFLOW:LOG1.PNT)
# ) OR ( (((EWS102/10DAS0D:TC1D027201.PNT + EWS102/10DAS0D:TC1D027202.PNT + EWS102/10DAS0D:TC1D027102.PNT)/3 - (EWS102/10DAS0B:TC1B023101.PNT +
# EWS102/10DAS0B:TC1B023102.PNT)/2) - ((EWS102/10DAS0D:RT1D012706.PNT + EWS102/10DAS0D:RT1D026402.PNT + EWS102/10DAS0D:RT1D012307.PNT)/3 -
# (EWS102/10DAS0D:RT1D026404.PNT + EWS102/10DAS0D:RT1D026406.PNT)/2)) / ln(((EWS102/10DAS0D:TC1D027201.PNT + EWS102/10DAS0D:TC1D027202.PNT +
# EWS102/10DAS0D:TC1D027102.PNT)/3 - (EWS102/10DAS0B:TC1B023101.PNT + EWS102/10DAS0B:TC1B023102.PNT)/2) / ((EWS102/10DAS0D:RT1D012706.PNT +
# EWS102/10DAS0D:RT1D026402.PNT + EWS102/10DAS0D:RT1D012307.PNT)/3 - (EWS102/10DAS0D:RT1D026404.PNT + EWS102/10DAS0D:RT1D026406.PNT)/2)) > -2.918 +
# 0.016*(EWS102/10DAS0O:AI1O013305.PNT) + 0.176*(EWS102/10DAS0E:TC1E047201.PNT) ))
#
# ====================================================================================================
# APH R :
#
# (( ((EWS102/10DAS0E:PT1E033603.PNT + EWS102/10DAS0E:PT1E032604.PNT)/2 - EWS102/10DAS0E:PT1E033604.PNT) > 91.427 +
# 0.213*(EWS102/10DAS0O:AI1O013305.PNT) + 8.538*(EWS102/10DAS0D:CT1D013307.PNT) ) OR ( (EWS102/10DAS0E:TC1E047202.PNT - (EWS102/10DAS0E:RT1E032706.PNT +
# EWS102/10DAS0E:RT1E046502.PNT + EWS102/10DAS0E:RT1E032307.PNT)/3) < -67.797 + 0.011*(EWS102/10DAS0O:AI1O013305.PNT) +
# 0.672*(EWS102/10DAS0E:TC1E047105.PNT) ) OR ( (((EWS102/10DAS0E:TC1E047104.PNT + EWS102/10DAS0E:TC1E047105.PNT + EWS102/10DAS0E:TC1E047204.PNT)/3 -
# (EWS102/10DAS0B:TC1B023201.PNT + EWS102/10DAS0B:TC1B023202.PNT)/2) - ((EWS102/10DAS0E:RT1E032706.PNT + EWS102/10DAS0E:RT1E046502.PNT +
# EWS102/10DAS0E:RT1E032307.PNT)/3 - (EWS102/10DAS0E:RT1E046504.PNT + EWS102/10DAS0E:RT1E046506.PNT)/2)) / ln(((EWS102/10DAS0E:TC1E047104.PNT +
# EWS102/10DAS0E:TC1E047105.PNT + EWS102/10DAS0E:TC1E047204.PNT)/3 - (EWS102/10DAS0B:TC1B023201.PNT + EWS102/10DAS0B:TC1B023202.PNT)/2) /
# ((EWS102/10DAS0E:RT1E032706.PNT + EWS102/10DAS0E:RT1E046502.PNT + EWS102/10DAS0E:RT1E032307.PNT)/3 - (EWS102/10DAS0E:RT1E046504.PNT +
# EWS102/10DAS0E:RT1E046506.PNT)/2)) > 5.873 + 0.020*(EWS102/10DAS0O:AI1O013305.PNT) + 0.144*(EWS102/10DAS0E:TC1E047202.PNT) ))
